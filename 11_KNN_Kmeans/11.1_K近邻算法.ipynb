# %% [markdown]
# # 11.1 K近邻算法

# %% [markdown]
# 请观看以下视频：

# %% [markdown]
# <iframe src="https://player.bilibili.com/player.html?isOutside=true&aid=116004197766486&bvid=BV1zYFGzEE6L&cid=35784297030&p=1&autoplay=0" allowfullscreen="allowfullscreen" width="80%" height="350" scrolling="no" frameborder="0" sandbox="allow-top-navigation allow-same-origin allow-forms allow-scripts"></iframe>
