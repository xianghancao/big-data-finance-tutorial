# %% [markdown]
# # 13 决策树

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>知识点：</b>_____
# <br><b>重点：</b>_____
# <br><b>难点：</b>_____
# </div>

# %% [markdown]
# 决策树算法是______。用途______。

# %% [markdown]
# ## 预习

# %% [markdown]
# xxxxx

# %% [markdown]
# ### 名词解释

# %% [markdown]
# 请使用网络工具和图书馆资源，完成以下名词解释：

# %% [markdown]
# - 决策树
# - xxx
# - xx
# - xx
# - xx
