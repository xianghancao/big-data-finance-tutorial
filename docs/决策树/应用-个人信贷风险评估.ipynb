# %% [markdown]
# # 13.2 决策树算法在个人信贷风险评估中的应用

# %% [markdown]
# ## 观看本章节视频

# %% [markdown]
# <iframe src="https://player.bilibili.com/player.html?isOutside=true&aid=115212648779835&bvid=BV14Hp1zLEmq&cid=32415811283&p=1&autoplay=0" allowfullscreen="allowfullscreen" width="100%" height="380" scrolling="no" frameborder="0" sandbox="allow-top-navigation allow-same-origin allow-forms allow-scripts"></iframe>
