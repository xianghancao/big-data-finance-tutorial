# %% [markdown]
# # 13.1 决策树算法

# %% [markdown]
# ## 观看本章节视频

# %% [markdown]
# <iframe src="https://player.bilibili.com/player.html?isOutside=true&aid=115167970988638&bvid=BV1VCadzVEB6&cid=32245612802&p=1&autoplay=0" allowfullscreen="allowfullscreen" width="100%" height="380" scrolling="no" frameborder="0" sandbox="allow-top-navigation allow-same-origin allow-forms allow-scripts"></iframe>
